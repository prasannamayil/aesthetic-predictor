# %%
import os
import sys

# %%
sys.path.append('/fast/pmayilvahanan/aesthetic-predictor')
os.chdir('/fast/pmayilvahanan/aesthetic-predictor')

# %%
# !python3 get_elo.py
# Out:
# Successfully loaded data from cleaned_data/AP_Data_Comparison_5K_050525_cleaned.csv
# Initializing Elo ratings...
# Processing 5000 comparisons...
# Scaling Elo ratings...
#
# --- Elo Ranking Results ---
#                                                                                                                                              url   elo_rating  rank  scaled_score_1_10
# 0                  https://food-cms.grab.com/Merchants/4-C6N3TLMWLU6XRN/photoexhibition/8fc7f816b21141cda52b2ae0bf8fc7da_1733208955316514851.jpg  1719.111188     1              10.00
# 1      https://d1sag4ddilekf6.cloudfront.net/Merchants/1-CZCEG4CVVXUANA/photoexhibition/619353a2baaa414796e325e22f45cd2d_1677082465560777275.jpg  1716.324152     2               9.94
# 2                  https://food-cms.grab.com/Merchants/4-C2L3LP6UJUDHGX/photoexhibition/4e5e4959b0ea4b5abea64273e14b631c_1732764635386106061.jpg  1714.601084     3               9.91
# ...
